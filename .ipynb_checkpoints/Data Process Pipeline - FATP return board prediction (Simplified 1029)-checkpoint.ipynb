# %% [markdown]
# # Data preprocess Pipeline

# %% [markdown]
# The purpose of this data process pipeline is to generate a DataFrame for FATP return board machine learning modeling.

# %% [markdown]
# ## Preprocess steps
# Step 1. Download necessary data (using HIVE) and tranform to DataFrame <br />
#     - FCT from test log csv (1 week)
#     - GateKeeper from Bobcat (2 weeks)
#     - RPC (4 weeks)
# Step 2. Join and filter data (X) <br />
# Step 3. Filter RPC data (y) <br />
# Step 4. Extract FCT test values (FCT['items']) and store it as a separate DataFrame <br />
# Step 5. Missing value handling before data scalling <br />
# Step 6. Data Scalling (Normalization, Max-Min Scalling) <br />
# Step 7. Missing value handling after data scalling <br />

# %% [markdown]
# ### Step 1. Download necessary data and tranform to DataFrame

# %% [markdown]
# #### a. ssh log in server **(10.195.223.53)** and download test log data with user specified date and period with HIVE, e.g station = **FCT**, date = 2015-10-26, period = 6 days (a week)

# %%
# !ssh mlb@10.195.223.53 "hive -e \"use cpk; select * from mlb_test_log_detail \
                        where station = 'FCT'\
                        and model = 'N66'\
                        and hour between '2015-10-29_00' and '2015-10-29_23';\"" \
                        > Data/FCT_20151029.log
# Out:
# 15/12/11 08:30:01 WARN conf.HiveConf: HiveConf of name hive.optimize.mapjoin.mapreduce does not exist
# 15/12/11 08:30:01 WARN conf.HiveConf: HiveConf of name hive.heapsize does not exist
# 15/12/11 08:30:01 WARN conf.HiveConf: HiveConf of name hive.server2.enable.impersonation does not exist
# 15/12/11 08:30:01 WARN conf.HiveConf: HiveConf of name hive.auto.convert.sortmerge.join.noconditionaltask does not exist
#
# Logging initialized using configuration in file:/etc/hive/conf/hive-log4j.properties
# SLF4J: Class path contains multiple SLF4J bindings.
# SLF4J: Found binding in [jar:file:/usr/hdp/2.2.6.0-2800/hadoop/lib/slf4j-log4j12-1.7.5.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: Found binding in [jar:file:/usr/hdp/2.2.6.0-2800/hive/lib/hive-jdbc-0.14.0.2.2.6.0-2800-standalone.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See http://www.slf4j.org/codes.html#multiple_bindings for an explanation.
# SLF4J: Actual binding is of type [org.slf4j.impl.Log4jLoggerFactory]
# OK
# Time taken: 2.029 seconds
# OK
# Time taken: 3.57 seconds, Fetched: 65658 row(s)

# %% [markdown]
# #### b. Download **BOBCAT** data with same date and period.

# %%
# !ssh mlb@10.195.223.53 "hive -e \"use cpk; select * from mlb_bobcat_raw \
                        where model = 'Agera'\
                        and day between '2015-10-26' and '2015-11-07';\"" \
                        > Data/Bobcat_20151026.log
# Out:
# 15/11/24 14:44:35 WARN conf.HiveConf: HiveConf of name hive.optimize.mapjoin.mapreduce does not exist
# 15/11/24 14:44:35 WARN conf.HiveConf: HiveConf of name hive.heapsize does not exist
# 15/11/24 14:44:35 WARN conf.HiveConf: HiveConf of name hive.server2.enable.impersonation does not exist
# 15/11/24 14:44:35 WARN conf.HiveConf: HiveConf of name hive.auto.convert.sortmerge.join.noconditionaltask does not exist
#
# Logging initialized using configuration in file:/etc/hive/conf/hive-log4j.properties
# SLF4J: Class path contains multiple SLF4J bindings.
# SLF4J: Found binding in [jar:file:/usr/hdp/2.2.6.0-2800/hadoop/lib/slf4j-log4j12-1.7.5.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: Found binding in [jar:file:/usr/hdp/2.2.6.0-2800/hive/lib/hive-jdbc-0.14.0.2.2.6.0-2800-standalone.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See http://www.slf4j.org/codes.html#multiple_bindings for an explanation.
# SLF4J: Actual binding is of type [org.slf4j.impl.Log4jLoggerFactory]
# OK
# Time taken: 2.014 seconds
# OK
# Time taken: 2.564 seconds, Fetched: 14757988 row(s)

# %% [markdown]
# #### c. Download RPC data with same starting date but period = 4 weeks

# %%
# !ssh mlb@zz2 "hive -e \"use cpk; select * from rpc_file\
                        where day between '2015-10-26' and '2015-11-21';\"" \
                        > Data/rpc_20151026.log
# Out:
# Logging initialized using configuration in file:/etc/hive/conf/hive-log4j.properties
# SLF4J: Class path contains multiple SLF4J bindings.
# SLF4J: Found binding in [jar:file:/usr/hdp/2.2.8.0-3150/hadoop/lib/slf4j-log4j12-1.7.5.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: Found binding in [jar:file:/usr/hdp/2.2.8.0-3150/hive/lib/hive-jdbc-0.14.0.2.2.8.0-3150-standalone.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See http://www.slf4j.org/codes.html#multiple_bindings for an explanation.
# SLF4J: Actual binding is of type [org.slf4j.impl.Log4jLoggerFactory]
# OK
# Time taken: 11.29 seconds
# OK
# Time taken: 2.042 seconds, Fetched: 8804653 row(s)

# %% [markdown]
# ## Step 2. Transform downloaded data to DataFrame
#
# In the following steps, we will use SparkSQL DataFrame to preprocess data

# %%
#Import necessary libraries

import findspark
findspark.init('/Users/hadoop1/srv/spark')
import pyspark
from pyspark import SparkContext
from pyspark.sql import SQLContext, HiveContext, Row
import pandas as pd
sc = pyspark.SparkContext()
hc = HiveContext(sc)

# %%
fctLines = sc.textFile("Data/FCT_20151026.log")

# %%
fctParts = fctLines.map(lambda l: l.split("\t"))

# %%
fctBoard = fctParts.map(lambda p: Row(serial_number=p[0], test_result=p[1], fct_test_time=p[2],\
                                     version=p[3],line=p[4],machine=p[5],\
                                     slot=p[7],items=p[8],model=p[10],station=p[11]))

# %%
fctBoardDf = hc.createDataFrame(fctBoard)

# %%
fctBoardDf.count()
# Out:
# 326511

# %%
fctBoardDf.show()
# Out:
# +-------------------+--------------------+-----------+-------+-----+----------------+----+-------+-----------+--------------------+
# |      fct_test_time|               items|       line|machine|model|   serial_number|slot|station|test_result|             version|
# +-------------------+--------------------+-----------+-------+-----+----------------+----+-------+-----------+--------------------+
# |2015-10-26 00:03:08|{"VREF_180mV_CHEC...|L06-2FRF-01|      9|  N66|F3Y54361944G360B|   1|    FCT|       PASS|7.26q_Agera_PVT_T...|
# |2015-10-26 00:03:08|{"VREF_180mV_CHEC...|L06-2FRF-01|      9|  N66|F3Y5436188QG360B|   2|    FCT|       PASS|7.26q_Agera_PVT_T...|
# |2015-10-26 00:03:08|{"VREF_180mV_CHEC...|L06-2FRF-01|      9|  N66|F3Y543619VYG360B|   3|    FCT|       PASS|7.26q_Agera_PVT_T...|
# |2015-10-26 00:03:08|{"VREF_180mV_CHEC...|L06-2FRF-01|      9|  N66|F3Y543619W0G360B|   4|    FCT|       PASS|7.26q_Agera_PVT_T...|
# |2015-10-26 00:00:23|{"VREF_180mV_CHEC...|L06-2FRF-01|     10|  N66|F3Y5436188PG360B|   1|    FCT|       PASS|7.26q_Agera_PVT_T...|
# |2015-10-26 00:00:23|{"VREF_180mV_CHEC...|L06-2FRF-01|     10|  N66|F3Y5436188RG360B|   2|    FCT|       PASS|7.26q_Agera_PVT_T...|
# |2015-10-26 00:00:23|{"VREF_180mV_CHEC...|L06-2FRF-01|     10|  N66|F3Y54361A0XG360B|   3|    FCT|       PASS|7.26q_Agera_PVT_T...|
# |2015-10-26 00:00:23|{"VREF_180mV_CHEC...|L06-2FRF-01|     10|  N66|F3Y543616J2G360B|   4|    FCT|       PASS|7.26q_Agera_PVT_T...|
# |2015-10-26 00:40:54|{"VREF_180mV_CHEC...|L05-2FRF-05|     10|  N66|F3Y5436177DG360B|   1|    FCT|       PASS|7.26q_Agera_PVT_T...|
# |2015-10-26 00:40:54|{"VREF_180mV_CHEC...|L05-2FRF-05|     10|  N66|F3Y54370Q6FG360B|   2|    FCT|       PASS|7.26q_Agera_PVT_T...|
# |2015-10-26 00:40:54|{"VREF_180mV_CHEC...|L05-2FRF-05|     10|  N66|F3Y54370Q6JG360B|   3|    FCT|       PASS|7.26q_Agera_PVT_T...|
# |2015-10-26 00:40:54|{"VREF_180mV_CHEC...|L05-2FRF-05|     10|  N66|F3Y54221GUJG360B|   4|    FCT|       FAIL|7.26q_Agera_PVT_T...|
# |2015-10-26 00:31:22|{"VREF_180mV_CHEC...|L05-2FRF-06|      7|  N66|F3Y54410PKHG360B|   1|    FCT|       PASS|7.26q_Agera_PVT_T...|
# |2015-10-26 00:31:22|{"VREF_180mV_CHEC...|L05-2FRF-06|      7|  N66|F3Y54410PKJG360B|   2|    FCT|       PASS|7.26q_Agera_PVT_T...|
# |2015-10-26 00:31:22|{"VREF_180mV_CHEC...|L05-2FRF-06|      7|  N66|F3Y54410PKKG360B|   3|    FCT|       PASS|7.26q_Agera_PVT_T...|
# |2015-10-26 00:31:22|{"VREF_180mV_CHEC...|L05-2FRF-06|      7|  N66|F3Y54410PKLG360B|   4|    FCT|       PASS|7.26q_Agera_PVT_T...|
# |2015-10-26 00:37:23|{"VREF_180mV_CHEC...|L05-2FRF-06|      7|  N66|F3Y54410BXYG360B|   1|    FCT|       PASS|7.26q_Agera_PVT_T...|
# |2015-10-26 00:37:23|{"VREF_180mV_CHEC...|L05-2FRF-06|      7|  N66|F3Y54410BXZG360B|   2|    FCT|       PASS|7.26q_Agera_PVT_T...|
# |2015-10-26 00:37:23|{"VREF_180mV_CHEC...|L05-2FRF-06|      7|  N66|F3Y54410BY0G360B|   3|    FCT|       PASS|7.26q_Agera_PVT_T...|
# |2015-10-26 00:37:23|{"VREF_180mV_CHEC...|L05-2FRF-06|      7|  N66|F3Y54410C7MG360B|   4|    FCT|       PASS|7.26q_Agera_PVT_T...|
# +-------------------+--------------------+-----------+-------+-----+----------------+----+-------+-----------+--------------------+
# only showing top 20 rows

# %% [markdown]
# **b. Bobcat **

# %% [markdown]
# 0	wip_no	string
# 1	test_time	string
# 2	test_hour	string
# 3	is_test_fail	string
# 4	symptom_code	string
# 5	symptom_code_first	string
# 6	factory	string
# 7	station	string
# 8	station_code	string
# 9	line	string
# 10	machine	string
# 11	line_type	string
# 12	test_times	int	3
# 13	rankno	int
# 14	fail_count	int
# 15	test_result	string
# 16	symptom	string
# 17	day	string
# 18	model	string

# %%
bobcatLines = sc.textFile('Data/Bobcat_20151026.log')

# %%
bobcatParts = bobcatLines.map(lambda l: l.split('\t'))

# %%
bobcatRows = bobcatParts.map(lambda p: Row(sympton = p[4], serial_num = p[0],test_time=p[1],station=p[7],test_result=p[15]))

# %%
bobcatDf = hc.createDataFrame(bobcatRows)

# %%
bobcatDf.show()
# Out:
# +----------------+------------------+--------------------+-----------+-------------------+
# |      serial_num|           station|             sympton|test_result|          test_time|
# +----------------+------------------+--------------------+-----------+-------------------+
# |F3Y54411DDKG35WB|          CELL-CAL|                    | First Pass|2015-10-26 18:15:57|
# |F3Y54411XJWG360B|GATEKEEPER-PREBURN|                    | First Pass|2015-10-26 20:51:26|
# |F3Y54411DDEG360B|          CELL-CAL|                    | First Pass|2015-10-26 13:31:30|
# |F3Y54411DCZG35WB|               FCT|                    | First Pass|2015-10-26 18:37:43|
# |F3Y54412JPBG35WB|     DFU-NAND-INIT|                    | First Pass|2015-10-26 18:09:08|
# |F3Y54411DCTG35WB|GATEKEEPER-PREBURN|                    |Retest Pass|2015-10-26 22:31:09|
# |F3Y54411DCTG35WB|GATEKEEPER-PREBURN|CB Error; SMT QT ...|Retest Pass|2015-10-26 21:09:53|
# |F3Y54411DCNG360B|GATEKEEPER-PREBURN|                    | First Pass|2015-10-26 20:42:48|
# |F3Y54411DCDG35WB|          SOC-TEST|                    | First Pass|2015-10-26 13:25:58|
# |F3Y54411DC2G360B|      WIFI-BT-COND|                    | First Pass|2015-10-26 14:14:49|
# |F3Y54411DC2G360B|         CELL-TEST|                    | First Pass|2015-10-26 15:45:48|
# |F3Y54412LHBG360B|          SOC-TEST|                    | First Pass|2015-10-26 21:10:20|
# |F3Y54411DBQG360B|      WIFI-BT-COND|                    | First Pass|2015-10-26 20:31:18|
# |F3Y54411DBQG360B|         CELL-TEST|                    | First Pass|2015-10-26 21:19:45|
# |F3Y544136LWG35WB|          SOC-TEST|                    | First Pass|2015-10-26 14:13:33|
# |F3Y544121C6G360B|            S-COND|                    | First Pass|2015-10-26 21:24:42|
# |F3Y54411DBGG35WB|          CELL-CAL|                    | First Pass|2015-10-26 16:18:06|
# |F3Y54411DB7G35WB|      WIFI-BT-COND|                    | First Pass|2015-10-26 21:20:54|
# |F3Y54411DB7G35WB|         CELL-TEST|                    | First Pass|2015-10-26 22:29:05|
# |F3Y54412APWG35WB|     DFU-NAND-INIT|                    | First Pass|2015-10-26 17:02:32|
# +----------------+------------------+--------------------+-----------+-------------------+
# only showing top 20 rows

# %% [markdown]
# **c. RPC Data**

# %% [markdown]
#  	Name	Type	Comment
# 0	namec	string
# 1	station_code	string
# 2	serial_num	string
# 3	add_date	string
# 4	emp	string
# 5	station_type	string
# 6	fail_location	string
# 7	code	string
# 8	desce	string
# 9	other	string
# 10	day	string

# %%
rpcLines = sc.textFile('Data/rpc_20151026.log')

# %%
rpcParts = rpcLines.map(lambda l: l.split('\t'))

# %%
rpcRows = rpcParts.map(lambda p: Row(namec = p[0],serial_num=p[2], add_date = p[3], emp = p[4],\
                                     fail_location=p[6], code = p[7], desce = p[8], day = p[10],\
                                     ))

# %%
rpcDf = hc.createDataFrame(rpcRows)

# %%
rpcDf.show()
# Out:
# +-------------------+----+----------+-----+---+-------------+---------+----------------+
# |           add_date|code|       day|desce|emp|fail_location|    namec|      serial_num|
# +-------------------+----+----------+-----+---+-------------+---------+----------------+
# |2015-10-26 00:00:20|    |2015-10-26|     |徐騰飛|             |Check Out|F3Y54331AFQG360B|
# |2015-10-26 00:00:21|    |2015-10-26|     |徐騰飛|             |Check Out|F3Y542601WQGKL0B|
# |2015-10-26 00:00:21|    |2015-10-26|     |徐騰飛|             |Check Out|F3Y543209DPGKL0B|
# |2015-10-26 00:00:22|    |2015-10-26|     |徐騰飛|             |Check Out|F3Y543302J0GKKYB|
# |2015-10-26 00:00:22|    |2015-10-26|     |徐騰飛|             |Check Out|F3Y543505FQGKKYB|
# |2015-10-26 00:00:23|    |2015-10-26|     |徐騰飛|             |Check Out|F3Y54312XXLG35WB|
# |2015-10-26 00:00:24|    |2015-10-26|     |徐騰飛|             |Check Out|F3Y543300Z7GKKYB|
# |2015-10-26 00:00:24|    |2015-10-26|     |徐騰飛|             |Check Out|F3Y54310JV4GKL0B|
# |2015-10-26 00:00:25|    |2015-10-26|     |徐騰飛|             |Check Out|F3Y54350GZ7GKL1B|
# |2015-10-26 00:00:26|    |2015-10-26|     |徐騰飛|             |Check Out|F3Y54260F27GKL0B|
# |2015-10-26 00:00:26|    |2015-10-26|     |徐騰飛|             |Check Out|F3Y5436202KG35WB|
# |2015-10-26 00:00:27|    |2015-10-26|     |徐騰飛|             |Check Out|F3Y54210GZ8G360B|
# |2015-10-26 00:00:27|    |2015-10-26|     |徐騰飛|             |Check Out|F3Y5435077RGKL0B|
# |2015-10-26 00:00:28|    |2015-10-26|     |徐騰飛|             |Check Out|F3Y54341MBLG35WB|
# |2015-10-26 00:00:28|    |2015-10-26|     |徐騰飛|             |Check Out|F3Y54340JF7GKL1B|
# |2015-10-26 00:00:29|    |2015-10-26|     |徐騰飛|             |Check Out|F3Y5417044PG35VB|
# |2015-10-26 00:00:30|    |2015-10-26|     |徐騰飛|             |Check Out|F3Y54350J62GKL1B|
# |2015-10-26 00:00:31|    |2015-10-26|     |徐騰飛|             |Check Out|F3Y54310KH0GKL0B|
# |2015-10-26 00:05:03|    |2015-10-26|     |徐騰飛|             |Check Out|F3Y541502CAG35VB|
# |2015-10-26 00:05:04|    |2015-10-26|     |徐騰飛|             |Check Out|F3Y54140ACKG360B|
# +-------------------+----+----------+-----+---+-------------+---------+----------------+
# only showing top 20 rows

# %% [markdown]
# ### Step 3. Join and filter data (X)
# Now we have 3 dataframes, fctBoardDf, bobcatDf and rpcDf.

# %%
fctBoardDf
# Out:
# DataFrame[fct_test_time: string, items: string, line: string, machine: string, model: string, serial_number: string, slot: string, station: string, test_result: string, version: string]

# %%
bobcatDf
# Out:
# DataFrame[serial_num: string, station: string, sympton: string, test_result: string, test_time: string]

# %%
rpcDf
# Out:
# DataFrame[add_date: string, code: string, day: string, desce: string, emp: string, fail_location: string, namec: string, serial_num: string]

# %% [markdown]
# And 3 temp tables for sql

# %%
fctBoardDf.registerTempTable("fctBoardDfTemp")

# %%
bobcatDf.registerTempTable("bobcatDfTemp")

# %%
rpcDf.registerTempTable("rpcDfTemp")

# %% [markdown]
# ### a. Join FCT ['test_result']==pass and Bobcat GATEKEEPER ['test_result']==First Pass I ['test_result']==Retest Pass  DataFrames on serial_num

# %% [markdown]
# First filter fctBoardDf DF with only PASS results, and verify its numbers.

# %%
fctBoardPassDf = fctBoardDf.filter(fctBoardDf.test_result == 'PASS')

# %%
fctBoardFailDf = fctBoardDf.filter(fctBoardDf.test_result == 'FAIL')

# %%
322198+4313
# Out:
# 326511

# %% [markdown]
# Use bobcatGkDf and filter out serial numbers that passed 'GATEKEEPER-PREBURN' stations. This filtered DF then work as a mask for fctBoardDfPass to make sure all serial numbers are passed at the last station.

# %%
bobcatGkPassDf = bobcatDf.filter((bobcatDf.station == 'GATEKEEPER-PREBURN'))\
                         .filter((bobcatDf.test_result == 'First Pass') | 
                                   (bobcatDf.test_result == 'Retest Pass'))

# %%
fctBoardPassDf.registerTempTable("fctBoardPassDfTemp")

# %%
bobcatGkPassDf.registerTempTable("bobcatGKPassDfTemp")

# %%
fctGateKeeper = fctBoardPassDf.join(bobcatGkPassDf, fctBoardPassDf.serial_number == bobcatGkPassDf.serial_num)

# %%
fctGateKeeper.count()
# Out:
# 250232

# %% [markdown]
# fctGateKeeper, fctGateKeeperSql are DFs that contain records that have passed FCT and GateKeeper test stations.

# %% [markdown]
# ### b. Join fctGateKeeperSql DF with bobcatDfFctPass DF on [serial_num] and [test_start_time] columns.

# %% [markdown]
# First join fctGateKeeper DF with bobcatDf DF to infer "First Pass" and "Retest Pass" information.

# %%
bobcatFctFirstPassDf = bobcatDf.filter(bobcatDf.station == 'FCT')\
                           .filter(bobcatDf.test_result == 'First Pass')

# %%
fctGateKeeper.registerTempTable("fctGateKeeperTemp")

# %%
bobcatFctFirstPassDf.registerTempTable("bobcatFctFirstPassDfTemp")

# %%
fctGateKeeperFirstPassDf = hc.sql("select F.serial_number, F.line, F.machine,\
                                      F.model, F.slot, F.fct_test_time, F.items, B.test_result\
                                      from fctGateKeeperTemp F\
                                      inner join bobcatFctFirstPassDfTemp B\
                                      on F.serial_number =\
                                      B.serial_num and F.fct_test_time = B.test_time")

# %%
fctGateKeeperFirstPassDf.registerTempTable("fctGateKeeperFirstPassDfTemp")

# %%
fctGateKeeperFirstPassDf.count()
# Out:
# 227232

# %% [markdown]
# ## Add a new column specify item numbers

# %% [markdown]
# The functions should be import from pyspark.sql, then we can use functions.udf to defince User Defined Functions.

# %%
from pyspark.sql import functions

# %% [markdown]
# When defining user defiend funciton, the type of the returned value should be specified beforehand, therefore the IntegerType shold also be imported.

# %%
from pyspark.sql.types import IntegerType

# %%
import ast

# %%
sparkItemToNum = functions.udf(lambda items: len(ast.literal_eval(items)), IntegerType())

# %%
fctGateKeeperFirstPassItemnumDf = fctGateKeeperFirstPassDf.withColumn('item_num',\
                                  sparkItemToNum(fctGateKeeperFirstPassDf.items))

# %%
fctGateKeeperFirstPass799Df = fctGateKeeperFirstPassItemnumDf.filter\
                        (fctGateKeeperFirstPassItemnumDf.item_num == 799)

# %%
fctGateKeeperFirstPass799Df.registerTempTable("fctGateKeeperFirstPass799DfTemp")

# %%
rpcDf.registerTempTable("rpcDfTemp")

# %%
fctGatekeeperAllpass799 = hc.sql("select * from fctGateKeeperFirstPass799DfTemp F\
                               left outer join rpcDfTemp R\
                               on F.serial_number = R.serial_num\
                               where R.serial_num is null")

# %%
fctGatekeeperCRBFail799 = hc.sql("select * from fctGateKeeperFirstPass799DfTemp F\
                            left semi join rpcDfTemp R\
                            on F.serial_number = R.serial_num\
                            and R.namec = 'CRB Check In'")

# %% [markdown]
# ### Step 4. Filter RPC data (y)

# %% [markdown]
# #### a. Filter RPC DataFrame by ['namec'] column and separate ['namec']=='TFB Check In' and ['namec']=='CRB Check In'. We need only 'CRB Check In' records.

# %% [markdown]
# #### b. Filter RPC records by 'NTF' and 'Replaced'.

# %% [markdown]
# #### c. Filter 'Replaced' records by 'AP' and 'RF'
#
# Note: AP-Application, RF-Radio Frequency
#       FCT test items are mainly for AP.

# %% [markdown]
# #### d. Filter RPC DataFrame by ['serial_num'].isin(above DataFrame['serial_num])

# %% [markdown]
# #### e. Join above DataFrame with RPC DataFrame to identify FATP return records.

# %% [markdown]
# ### Step 5. Extract FCT test values (FCT['items']) and store it as a separate DataFrame

# %% [markdown]
# #### a. The test values of FCT test station are stored as mapped file within FCT['items'] column. Extract these values and stored them as a separate DataFrame. Remaining columns of original DataFrame are stored as a metadata DataFrame.

# %% [markdown]
# **At this point, we have joined and generated 2 dataframes:**
# - fctGatekeeperAllpass(223041)
# - fctGatekeeperCRBFail(3126)
#
# Both dataframes have 1 column called 'items' that contain FCT test log values, that will be used for building anomaly detection model. We will first extract FCT test log values from this 2 dataframes and stored them as a separate dataframe.

# %%
import ast

# %%
def dic_to_row(record):
    schema = {'{i:s}'.format(i = key):record[key] for key in record}
    return Row(**schema)

# %%
itemsCRBFailRow = fctGatekeeperCRBFail799.map(lambda row: row.items)\
                                .map(lambda s: ast.literal_eval(s))\
                                .map(lambda d: dic_to_row(d))

# %%
itemsCRBFailRow.take(1)
# Out:
# [Row(BATT_VCC_SHORT_CHECK='0.096597', CT_BT_delta='6.375548999999921', CT_BT_off='275.594482', CT_BT_on='277.5264279999999', CT_Phosphorus_baseline='230.7730409999999', CT_Phosphorus_delta='1.545547000000027', CT_Phosphorus_sampling='232.318588', CT_acc_load_delta='112.5367739999999', CT_acc_load_off='230.483246', CT_acc_load_on='343.0200199999999', CT_accel_delta='0.965972999999991', CT_accel_off='230.676437', CT_accel_sampling='231.64241', CT_arc_boost_8V_delta='79.59686199999998', CT_arc_boost_8V_on='342.247253', CT_arc_delta='32.07054200000001', CT_arc_off='230.5798489999999', CT_arc_on='262.650391', CT_bl_baseline='230.0968629999999', CT_bl_high_22000='593.691956', CT_bl_high_22000_delta='363.595093', CT_bl_low_5500='318.5805969999999', CT_bl_low_5500_delta='88.48373399999996', CT_bl_med_12600='434.3050539999999', CT_bl_med_12600_delta='204.2081909999999', CT_bl_off='230.2900539999999', CT_bl_off_delta='0.1931909999999845', CT_buck6_off='230.386658', CT_buck6_pfm='230.483246', CT_buck6_pfm_delta='0.09658800000002544', CT_buck6_pwm='235.216476', CT_buck6_pwm_delta='4.829817999999988', CT_codec_baseline='230.2900539999999', CT_codec_delta='0.2897950000000264', CT_codec_hp_aout='236.375641', CT_codec_hp_aout_delta='6.085587000000032', CT_codec_mic_bias='232.125397', CT_codec_mic_bias_delta='1.835343000000051', CT_codec_off='230.2900539999999', CT_codec_on='230.5798489999999', CT_compass_delta='0.8693690000000061', CT_compass_off='230.869629', CT_compass_sampling='231.738998', CT_gpu_perf0='230.676437', CT_gpu_perf1='280.9073179999999', CT_gpu_perf1_0_delta='50.23088099999989', CT_gpu_perf2='281.7766719999999', CT_gpu_perf2_0_delta='51.10023499999994', CT_gpu_perf3='282.742645', CT_gpu_perf3_0_delta='52.06620800000001', CT_gpu_perf4='287.1864009999999', CT_gpu_perf4_0_delta='56.50996399999996', CT_gyro_delta='2.318328999999977', CT_gyro_off='230.676437', CT_gyro_sampling='232.9947659999999', CT_l21_arc_VBST='8.1822', CT_l21_spk_VBST='8.1849', CT_mojave_delta='7.051712000000009', CT_mojave_off='230.676437', CT_mojave_on='237.728149', CT_nand_cgpg_baseline='230.676437', CT_nand_cgpg_delta='93.99006600000001', CT_nand_cgpg_off='230.193466', CT_nand_cgpg_off_delta='-0.4829710000000205', CT_nand_cgpg_on='136.2033999999999', CT_perfstate_0='230.5798489999999', CT_perfstate_1='235.3130799999999', CT_perfstate_1_0_delta='4.733230999999989', CT_perfstate_2='254.2463229999999', CT_perfstate_2_0_delta='23.66647399999999', CT_perfstate_3='261.2012939999999', CT_perfstate_3_0_delta='30.62144499999996', CT_perfstate_4='275.9808649999999', CT_perfstate_4_0_delta='45.40101599999999', CT_perfstate_5='301.289642', CT_perfstate_5_0_delta='70.70979300000001', CT_pfm_baseline='170.0126799999999', CT_pwm_baseline='229.7104799999999', CT_soc_perf0='230.676437', CT_soc_perf1='243.813736', CT_soc_perf1_0_delta='13.13729899999998', CT_speaker_delta='32.65013199999992', CT_speaker_off='230.676437', CT_speaker_on='263.3265689999999', CT_sphere_baseline='230.7730409999999', CT_sphere_mode0_delta='9.27342200000001', CT_sphere_mode0_on='240.0464629999999', CT_sphere_mode1_delta='7.34149099999999', CT_sphere_mode1_on='238.1145319999999', CT_spk_boost_8V_delta='80.94903500000003', CT_spk_boost_8V_on='344.2756039999999', CT_stockholm_delta='6.568573000000014', CT_stockholm_off='230.7730409999999', CT_stockholm_on='237.3416139999999', CT_strobe_baseline='243.813736', CT_strobe_cool='277.6230159999999', CT_strobe_cool_delta='33.80927999999994', CT_strobe_delta='34.00248699999997', CT_strobe_off='243.910339', CT_strobe_off_delta='0.09660300000001598', CT_strobe_on='277.8162229999999', CT_strobe_warm='277.3332209999999', CT_strobe_warm_delta='33.51948499999997', CT_wifi_BT_delta='46.75338699999997', CT_wifi_BT_off='229.7104799999999', CT_wifi_delta='40.37783800000005', CT_wifi_off='230.7730409999999', CT_wifi_on='271.150879', Gpu_mode0_Buck1_target_dvfm_delta='0', Gpu_mode1_Buck1_target_dvfm_delta='1', Gpu_mode2_Buck1_target_dvfm_delta='3', Gpu_mode3_Buck1_target ...

# %%
itemsCRBFailDf = hc.createDataFrame(itemsCRBFailRow)

# %%
itemsCRBFailDf.take(1)
# Out:
delta=u'70.70979300000001', CT_pfm_baseline=u'170.0126799999999', CT_pwm_baseline=u'229.7104799999999', CT_soc_perf0=u'230.676437', CT_soc_perf1=u'243.813736', CT_soc_perf1_0_delta=u'13.13729899999998', CT_speaker_delta=u'32.65013199999992', CT_speaker_off=u'230.676437', CT_speaker_on=u'263.3265689999999', CT_sphere_baseline=u'230.7730409999999', CT_sphere_mode0_delta=u'9.27342200000001', CT_sphere_mode0_on=u'240.0464629999999', CT_sphere_mode1_delta=u'7.34149099999999', CT_sphere_mode1_on=u'238.1145319999999', CT_spk_boost_8V_delta=u'80.94903500000003', CT_spk_boost_8V_on=u'344.2756039999999', CT_stockholm_delta=u'6.568573000000014', CT_stockholm_off=u'230.7730409999999', CT_stockholm_on=u'237.3416139999999', CT_strobe_baseline=u'243.813736', CT_strobe_cool=u'277.6230159999999', CT_strobe_cool_delta=u'33.80927999999994', CT_strobe_delta=u'34.00248699999997', CT_strobe_off=u'243.910339', CT_strobe_off_delta=u'0.09660300000001598', CT_strobe_on=u'277.8162229999999', CT_strobe_warm=u'277.3332209999999', CT_strobe_warm_delta=u'33.51948499999997', CT_wifi_BT_delta=u'46.75338699999997', CT_wifi_BT_off=u'229.7104799999999', CT_wifi_delta=u'40.37783800000005', CT_wifi_off=u'230.7730409999999', CT_wifi_on=u'271.150879', Gpu_mode0_Buck1_target_dvfm_del ...

# %%
itemsCRBFailDf.count()
# Out:
# 3126

# %%
itemsAllpassRow = fctGatekeeperAllpass799.map(lambda row: row.items)\
                                      .map(lambda items: ast.literal_eval(items))\
                                      .map(lambda dic: dic_to_row(dic))

# %%
itemsAllpassDf = hc.createDataFrame(itemsAllpassRow)

# %%
itemsAllpassDf.count()
# Out:
# 223041

# %%
itemsAllpassDf.take(1)
# Out:
# [Row(BATT_VCC_SHORT_CHECK=u'0.097813', CT_BT_delta=u'6.162506000000007', CT_BT_off=u'289.7260739999999', CT_BT_on=u'290.802002', CT_Phosphorus_baseline=u'242.383911', CT_Phosphorus_delta=u'1.662826999999993', CT_Phosphorus_sampling=u'244.046738', CT_acc_load_delta=u'114.6381229999999', CT_acc_load_off=u'242.2861019999999', CT_acc_load_on=u'356.9242249999999', CT_accel_delta=u'0.8803100000000086', CT_accel_off=u'242.481735', CT_accel_sampling=u'243.362045', CT_arc_boost_8V_delta=u'79.81661999999994', CT_arc_boost_8V_on=u'354.8702999999999', CT_arc_delta=u'32.66976900000003', CT_arc_off=u'242.383911', CT_arc_on=u'275.05368', CT_bl_baseline=u'241.797043', CT_bl_high_22000=u'605.17688', CT_bl_high_22000_delta=u'363.379837', CT_bl_low_5500=u'329.7319639999999', CT_bl_low_5500_delta=u'87.93492099999994', CT_bl_med_12600=u'445.3485109999999', CT_bl_med_12600_delta=u'203.5514679999999', CT_bl_off=u'242.188293', CT_bl_off_delta=u'0.3912500000000136', CT_buck6_off=u'242.2861019999999', CT_buck6_pfm=u'242.2861019999999', CT_buck6_pfm_delta=u'0', CT_buck6_pwm=u'247.2745509999999', CT_buck6_pwm_delta=u'4.988448999999946', CT_codec_baseline=u'242
------+------------------+-----------------+-----------------+-----------------+-----------------+-----------------+----------------------+-----------------+--------------------+-----------------+---------------------+-----------------+-------------------+-----------------+-----------------+-------------------+-----------------+------------------+-----------------+-------------------+-----------------+----------------------+-----------------+-----------------------+-----------------+-----------------+------------------+-----------------+-------------------+-----------------+-----------------+--------------------+-----------------+--------------------+-----------------+--------------------+-----------------+--------------------+-----------------+-----------------+-----------------+---------------+---------------+-----------------+-----------------+-----------------+---------------------+------------------+-----------------+----------------------+-----------------+-----------------+-----------------+----------------------+-----------------+----------------------+-----------------+----------------------+-----------------+----------------------+-----------------+----------------------+-----------------+-----------------+-----------------+-----------------+--------------------+-----------------+-----------------+-----------------+------------------+---------------------+------------------+---------------------+------------------+---------------------+------------------+------------------+-----------------+-----------------+------------------+-----------------+--------------------+-----------------+-----------------+-------------------+-----------------+-----------------+--------------------+-----------------+-----------------+-----------------+-----------------+-----------------+---------------------------------+---------------------------------+---------------------------------+---------------------------------+---------------------------------+-----------------------+-----------------------+---------------------+-----------------------+-----------------------+---------------------+-----------------------+-----------------------+---------------------+-----------------------+-----------------------+---------------------+-----------------------+-----------------------+---------------------+-----------------------+-----------------------+---------------------+-----------------------+-----------------------+---------------------+-----------------------+-----------------------+---------------------+-----------------------+-----------------------+---------------------+-----------------------+-----------------------+---------------------+-----------------------+-----------------------+---------------------+-----------------------+---------------------+-----------------------+---------------------+---------------+------------+------------------+--------------------+------------+------------------+--------------+----------------------+--------------+---------------------+----------------+----------+------------------------+----------------------+------------------------+---------------------------+-------------------------+---------------------------+------------------------+----------------------+------------------------+------------------+----------------+------------------+-----------------+-------------+---------------+--------------+--------------------+------------------+-----------+------------------------------+----------------------------+------------------------------+------------------------------+----------------------------+------------------------------+------------------------------+----------------------------+------------------------------+---------------------- ...
# |BATT_VCC_SHORT_CHECK|      CT_BT_delta|        CT_BT_off|         CT_BT_on|CT_Phosphorus_baseline|CT_Phosphorus_delta|CT_Phosphorus_sampling|CT_acc_load_delta|  CT_acc_load_off|   CT_acc_load_on|    CT_accel_delta|     CT_accel_off|CT_accel_sampling|CT_arc_boost_8V_delta|CT_arc_boost_8V_on|     CT_arc_delta|       CT_arc_off|        CT_arc_on|   CT_bl_baseline| CT_bl_high_22000|CT_bl_high_22000_delta|   CT_bl_low_5500|CT_bl_low_5500_delta|  CT_bl_med_12600|CT_bl_med_12600_delta|        CT_bl_off|    CT_bl_off_delta|     CT_buck6_off|     CT_buck6_pfm| CT_buck6_pfm_delta|     CT_buck6_pwm|CT_buck6_pwm_delta|CT_codec_baseline|     CT_codec_delta| CT_codec_hp_aout|CT_codec_hp_aout_delta|CT_codec_mic_bias|CT_codec_mic_bias_delta|     CT_codec_off|      CT_codec_on|  CT_compass_delta|   CT_compass_off|CT_compass_sampling|     CT_gpu_perf0|     CT_gpu_perf1|CT_gpu_perf1_0_delta|     CT_gpu_perf2|CT_gpu_perf2_0_delta|     CT_gpu_perf3|CT_gpu_perf3_0_delta|     CT_gpu_perf4|CT_gpu_perf4_0_delta|    CT_gyro_delta|      CT_gyro_off| CT_gyro_sampling|CT_l21_arc_VBST|CT_l21_spk_VBST|  CT_mojave_delta|    CT_mojave_off|     CT_mojave_on|CT_nand_cgpg_baseline|CT_nand_cgpg_delta| CT_nand_cgpg_off|CT_nand_cgpg_off_delta|  CT_nand_cgpg_on|   CT_perfstate_0|   CT_perfstate_1|CT_perfstate_1_0_delta|   CT_perfstate_2|CT_perfstate_2_0_delta|   CT_perfstate_3|CT_perfstate_3_0_delta|   CT_perfstate_4|CT_perfstate_4_0_delta|   CT_perfstate_5|CT_perfstate_5_0_delta|  CT_pfm_baseline|  CT_pwm_baseline|     CT_soc_perf0|     CT_soc_perf1|CT_soc_perf1_0_delta| CT_speaker_delta|   CT_speaker_off|    CT_speaker_on|CT_sphere_baseline|CT_sphere_mode0_delta|CT_sphere_mode0_on|CT_sphere_mode1_delta|CT_sphere_mode1_on|CT_spk_boost_8V_delta|CT_spk_boost_8V_on|CT_stockholm_delta| CT_stockholm_off|  CT_stockholm_on|CT_strobe_baseline|   CT_strobe_cool|CT_strobe_cool_delta|  CT_strobe_delta|    CT_strobe_off|CT_strobe_off_delta|     CT_strobe_on|   CT_strobe_warm|CT_strobe_warm_delta| CT_wifi_BT_delta|   CT_wifi_BT_off|    CT_wifi_delta|      CT_wifi_off|       CT_wifi_on|Gpu_mode0_Buck1_target_dvfm_delta|Gpu_mode1_Buck1_target_dvfm_delta|Gpu_mode2_Buck1_target_dvfm_delta|Gpu_mode3_Buck1_target_dvfm_delta|Gpu_mode4_Buck1_target_dvfm_delta|H8P_Cpu_perf0_Bin_Index|H8P_Cpu_perf0_Frequency|H8P_Cpu_perf0_Voltage|H8P_Cpu_perf1_Bin_Index|H8P_Cpu_perf1_Frequency|H8P_Cpu_perf1_Voltage|H8P_Cpu_perf2_Bin_Index|H8P_Cpu_perf2_Frequency|H8P_Cpu_perf2_Voltage|H8P_Cpu_perf3_Bin_Index|H8P_Cpu_perf3_Frequency|H8P_Cpu_perf3_Voltage|H8P_Cpu_perf4_Bin_Index|H8P_Cpu_perf4_Frequency|H8P_Cpu_perf4_Voltage|H8P_Cpu_perf5_Bin_Index|H8P_Cpu_perf5_Frequency|H8P_Cpu_perf5_Voltage|H8P_Cpu_perf6_Bin_Index|H8P_Cpu_perf6_Frequency|H8P_Cpu_perf6_Voltage|H8P_Gpu_mode1_Bin_Index|H8P_Gpu_mode1_Frequency|H8P_Gpu_mode1_Voltage|H8P_Gpu_mode2_Bin_Index|H8P_Gpu_mode2_Frequency|H8P_Gpu_mode2_Voltage|H8P_Gpu_mode3_Bin_Index|H8P_Gpu_mode3_Frequency|H8P_Gpu_mode3_Voltage|H8P_Gpu_mode4_Bin_Index|H8P_Gpu_mode4_Frequency|H8P_Gpu_mode4_Voltage|H8P_SoC_mode1_Bin_Index|H8P_SoC_mode1_Voltage|H8P_SoC_mode2_Bin_Index|H8P_SoC_mode2_Voltage|H8P_binning_rev|H8P_board_id|H8P_cpu_io_leakage|H8P_fixed_io_leakage|H8P_fuse_rev|H8P_gpu_io_leakage|H8P_io_leakage|H8P_vdd_var_io_leakage|Hibernate_IBAT|Hibernate_detect_IBAT|HoldKey_no_short|IBAT_RESET|PMU_TDEV1_forehead_delta|PMU_TDEV1_forehead_end|PMU_TDEV1_
------------+-----------------------+-----------------------+---------------------+-----------------------+-----------------------+---------------------+-----------------------+-----------------------+---------------------+-----------------------+-----------------------+---------------------+-----------------------+-----------------------+---------------------+-----------------------+-----------------------+---------------------+-----------------------+-----------------------+---------------------+-----------------------+-----------------------+---------------------+-----------------------+-----------------------+---------------------+-----------------------+-----------------------+---------------------+-----------------------+-----------------------+---------------------+-----------------------+---------------------+-----------------------+---------------------+---------------+------------+------------------+--------------------+------------+------------------+--------------+----------------------+--------------+---------------------+----------------+----------+------------------------+----------------------+------------------------+---------------------------+-------------------------+---------------------------+------------------------+----------------------+------------------------+------------------+----------------+------------------+-----------------+-------------+---------------+--------------+--------------------+------------------+-----------+------------------------------+----------------------------+------------------------------+------------------------------+----------------------------+------------------------------+------------------------------+----------------------------+------------------------------+---------------------- ...
# only showing top 20 rows

# %%
itemsAllpassPdf = fctGatekeeperCRBFail799.toPandas()
# Out:
# Traceback (most recent call last):
#   File "/Users/hadoop1/anaconda/lib/python2.7/SocketServer.py", line 295, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/Users/hadoop1/anaconda/lib/python2.7/SocketServer.py", line 321, in process_request
#     self.finish_request(request, client_address)
#   File "/Users/hadoop1/anaconda/lib/python2.7/SocketServer.py", line 334, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/Users/hadoop1/anaconda/lib/python2.7/SocketServer.py", line 655, in __init__
#     self.handle()
#   File "/Users/hadoop1/srv/spark/python/pyspark/accumulators.py", line 235, in handle
#     num_updates = read_int(self.rfile)
#   File "/Users/hadoop1/srv/spark/python/pyspark/serializers.py", line 545, in read_int
#     raise EOFError
# EOFError
# ERROR:py4j.java_gateway:Error while sending or receiving.
# Traceback (most recent call last):
#   File "/Users/hadoop1/srv/spark/python/lib/py4j-0.8.2.1-src.zip/py4j/java_gateway.py", line 479, in send_command
#     raise Py4JError("Answer from Java side is empty")
# Py4JError: Answer from Java side is empty
# ERROR:py4j.java_gateway:An error occurred while trying to connect to the Java server
# Traceback (most recent call last):
#   File "/Users/hadoop1/srv/spark/python/lib/py4j-0.8.2.1-src.zip/py4j/java_gateway.py", line 425, in start
#     self.socket.connect((self.address, self.port))
#   File "/Users/hadoop1/anaconda/lib/python2.7/socket.py", line 228, in meth
#     return getattr(self._sock,name)(*args)
# error: [Errno 61] Connection refused
# ----------------------------------------
# Exception happened during processing of request from ('127.0.0.1', 49830)
# ----------------------------------------
# ---------------------------------------------------------------------------
# Py4JNetworkError                          Traceback (most recent call last)
# <ipython-input-78-22a8ac37f820> in <module>()
# ----> 1 itemsAllpassPdf = fctGatekeeperCRBFail799.toPandas()
#
# /Users/hadoop1/srv/spark/python/pyspark/sql/dataframe.pyc in toPandas(self)
#    1272         """
#    1273         import pandas as pd
# -> 1274         return pd.DataFrame.from_records(self.collect(), columns=self.columns)
#    1275
#    1276     ##########################################################################################
#
# /Users/hadoop1/srv/spark/python/pyspark/sql/dataframe.pyc in collect(self)
#     276         [Row(age=2, name=u'Alice'), Row(age=5, name=u'Bob')]
#     277         """
# --> 278         with SCCallSiteSync(self._sc) as css:
#     279             port = self._sc._jvm.PythonRDD.collectAndServe(self._jdf.javaToPython().rdd())
#     280         return list(_load_from_socket(port, BatchedSerializer(PickleSerializer())))
#
# /Users/hadoop1/srv/spark/python/pyspark/traceback_utils.pyc in __enter__(self)
#      70     def __enter__(self):
#      71         if SCCallSiteSync._spark_stack_depth == 0:
# ---> 72             self._context._jsc.setCallSite(self._call_site)
#      73         SCCallSiteSync._spark_stack_depth += 1
#      74
#
# /Users/hadoop1/srv/spark/python/lib/py4j-0.8.2.1-src.zip/py4j/java_gateway.py in __call__(self, *args)
#     534             END_COMMAND_PART
#     535
# --> 536         answer = self.gateway_client.send_command(command)
#     537         return_value = get_return_value(answer, self.gateway_client,
#     538                 self.target_id, self.name)
#
# /Users/hadoop1/srv/spark/python/lib/py4j-0.8.2.1-src.zip/py4j/java_gateway.py in send_command(self, command, retry)
#     367             if retry:
#     368                 #print_exc()
# --> 369                 response = self.send_command(command)
#     370             else:
#     371                 response = ERROR
#
# /Users/hadoop1/srv/spark/python/lib/py4j-0.8.2.1-src.zip/py4j/java_gateway.py in send_command(self, command, retry)
#     360          the Py4J protocol.
#     361         """
# --> 362         connection = self._get_connection()
#     363         try:
#     364             response = connection.send_command(command)
#
# /Users/hadoop1/srv/spark/python/lib/py4j-0.8.2.1-src.zip/py4j/java_gateway.py in _get_connection(self)
#     316             connection = self.deque.pop()
#     317         except Exception:
# --> 318             connection = self._create_connection()
#     319         return connection
#     320
#
# /Users/hadoop1/srv/spark/python/lib/py4j-0.8.2.1-src.zip/py4j/java_gateway.py in _create_connection(self)
#     323         connection = GatewayConnection(self.address, self.port,
#     324                 self.auto_close, self.gateway_property)
# --> 325         connection.start()
#     326         return connection
#     327
#
# /Users/hadoop1/srv/spark/python/lib/py4j-0.8.2.1-src.zip/py4j/java_gateway.py in start(self)
#     430                 'server'
#     431             logger.exception(msg)
# --> 432             raise Py4JNetworkError(msg)
#     433
#     434     def close(self):
#
# Py4JNetworkError: An error occurred while trying to connect to the Java server

# %% [markdown]
# ** At this point, we have separate test log as a different dataframe, therefore now we have 4 dataframes:**
#
# (without excluding S/N having less than 799 items)
# 1. fctGatekeeperAllpass (223041)
# 2. itemsAllpassDf (223041)
# 3. fctGatekeeperCRBFail (3126)
# 4. itemsCRBFailDf (3126)
#
# (after excluding S/N having less than 799 items)
# 1. fctGatekeeperAllpass799 (222836)
# 2. itemsAllpassDf (222836)
# 3. fctGatekeeperCRBFail799 (3117)
# 4. itemsCRBFailDf (3117)

# %% [markdown]
# #### b. Examine extracted FCT test value DataFrame to make sure all records are in the same lengh.

# %%
len(itemsAllpassDf.take(1)[0])
# Out:
# 799

# %%
itemNumAllpass = itemsAllpassDf.map(lambda row: len(row))\
                               .filter(lambda a: a<799)

# %%
itemNumAllpass.count()
# Out:
# 205

# %% [markdown]
# #### c. Drop off records with fewer or missing test items. If there were records being dropped, remove relevant records with record index to make sure test item value DataFrame and meta data DataFrame are having same record number.

# %% [markdown]
# ### Step 6. Missing value handling before data scalling

# %% [markdown]
# #### a. Examine missing value.

# %% [markdown]
# ### Step 7. Data Scalling (Normalization, Max-Min Scalling)

# %% [markdown]
# #### a. Rescale FCT test log DataFrame with normalization and max-min scalling.

# %% [markdown]
# ### Step 8. Missing value handling after data scalling

# %% [markdown]
# #### a. Replace missing value with column.min()
#
# Note: Most of the observed missing value were due to incorrect scientific notation. Whenver the number is too small, the scientific notation will be displayed incorrectly, therefore we take min() value of each column to fill out missing values.
